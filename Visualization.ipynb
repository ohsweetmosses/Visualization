# %%
pip install seaborn matplotlib
# Out:
# Collecting seabornNote: you may need to restart the kernel to use updated packages.
#
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: matplotlib in c:\users\dell\miniconda3\envs\sunway\lib\site-packages (3.7.4)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dell\miniconda3\envs\sunway\lib\site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\dell\miniconda3\envs\sunway\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\miniconda3\envs\sunway\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\miniconda3\envs\sunway\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\miniconda3\envs\sunway\lib\site-packages (from matplotlib) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\miniconda3\envs\sunway\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\miniconda3\envs\sunway\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\miniconda3\envs\sunway\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\miniconda3\envs\sunway\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\miniconda3\envs\sunway\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\dell\miniconda3\envs\sunway\lib\site-packages (from matplotlib) (6.1.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\dell\miniconda3\envs\sunway\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\miniconda3\envs\sunway\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dell\miniconda3\envs\sunway\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\dell\miniconda3\envs\sunway\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 330.3 kB/s eta 0:00:01
#    -------- ------------------------------ 61.4/294.9 kB 365.7 kB/s eta 0:00:01
#    --------------- ---------------------- 122.9/294.9 kB 602.4 kB/s eta 0:00:01
#    ------------------------- ------------ 194.6/294.9 kB 787.7 kB/s eta 0:00:01
#    ------------------------------------ - 286.7/294.9 kB 983.9 kB/s eta 0:00:01
#    -------------------------------------- 294.9/294.9 kB 867.9 kB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('ds_salaries.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.shape
# Out:
# (3755, 11)

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3755.000000  3.755000e+03    3755.000000   3755.000000
# mean   2022.373635  1.906956e+05  137570.389880     46.271638
# std       0.691448  6.716765e+05   63055.625278     48.589050
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   95000.000000      0.000000
# 50%    2022.000000  1.380000e+05  135000.000000      0.000000
# 75%    2023.000000  1.800000e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %%
# Check for missing values
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
# Display summary statistics for numerical columns
summary_stats = df.describe()
print(summary_stats)

# Explore the distribution of salaries
plt.figure(figsize=(10, 6))
sns.histplot(df['salary_in_usd'], bins=30, kde=True)
plt.title('Distribution of Salaries in USD')
plt.xlabel('Salary (USD)')
plt.ylabel('Frequency')
plt.show()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3755.000000  3.755000e+03    3755.000000   3755.000000
# mean   2022.373635  1.906956e+05  137570.389880     46.271638
# std       0.691448  6.716765e+05   63055.625278     48.589050
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   95000.000000      0.000000
# 50%    2022.000000  1.380000e+05  135000.000000      0.000000
# 75%    2023.000000  1.800000e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %% [markdown]
# ## The histogram will give us insights into the overall salary distribution in the dataset.

# %% [markdown]
# # Explore the impact of experience levels on salaries

# %%
palette = {'EN': 'blue', 'MI': 'green', 'SE': 'orange', 'EX': 'red'}

plt.figure(figsize=(12, 8))
sns.boxplot(x='experience_level', y='salary_in_usd', data=df, order=['EN', 'MI', 'SE', 'EX'], palette=palette)
plt.title('Impact of Experience Level on Salaries')
plt.xlabel('Experience Level')
plt.ylabel('Salary (USD)')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19884\2763865566.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='experience_level', y='salary_in_usd', data=df, order=['EN', 'MI', 'SE', 'EX'], palette=palette)

# %% [markdown]
# ### This code generates a boxplot that visualizes the distribution of salaries for different experience levels (EN: Entry-level, MI: Mid-level, SE: Senior-level, EX: Executive-level). The boxplot provides insights into the central tendency, spread, and potential outliers for each experience level.

# %% [markdown]
# #### Explore the impact of employment types on salaries

# %%
palette = {'PT': 'blue', 'FT': 'green', 'CT': 'orange', 'FL': 'red'}

plt.figure(figsize=(12, 8))
sns.boxplot(x='employment_type', y='salary_in_usd', data=df, order=['PT', 'FT', 'CT', 'FL'], palette=palette)
plt.title('Impact of Employment Type on Salaries')
plt.xlabel('Employment Type')
plt.ylabel('Salary (USD)')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19884\3168831625.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='employment_type', y='salary_in_usd', data=df, order=['PT', 'FT', 'CT', 'FL'], palette=palette)

# %% [markdown]
# #### This code generates a boxplot that visualizes the distribution of salaries for different employment types (PT: Part-time, FT: Full-time, CT: Contract, FL: Freelance). The boxplot helps in comparing the central tendency, spread, and potential outliers for each employment type.

# %% [markdown]
# ## Identify the top 10 or 20 job titles with the highest median salary

# %%
# Identify the top 20 job titles with the highest median salary
top_job_titles = df.groupby('job_title')['salary_in_usd'].median().nlargest(20).index

# Define a color palette for the top job titles
palette = sns.color_palette("husl", len(top_job_titles))

# Filter the dataset for the top job titles
df_top_jobs = df[df['job_title'].isin(top_job_titles)]

# Create a bar chart to show the highest-paying job titles and their distribution
plt.figure(figsize=(16, 8))
sns.barplot(x='salary_in_usd', y='job_title', data=df_top_jobs, order=top_job_titles, palette=palette)
plt.title('Top 20 Job Titles with Highest Median Salaries')
plt.xlabel('Median Salary (USD)')
plt.ylabel('Job Title')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19884\3651985645.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='salary_in_usd', y='job_title', data=df_top_jobs, order=top_job_titles, palette=palette)

# %% [markdown]
# ## Identify the top 10 or 20 job titles with the highest median salary

# %%
# Identify the top 10 job titles with the highest median salary
top_job_titles = df.groupby('job_title')['salary_in_usd'].median().nlargest(10).index

# Define a color palette for the top job titles
palette = sns.color_palette("Set2")

# Filter the dataset for the top job titles
df_top_jobs = df[df['job_title'].isin(top_job_titles)]

# Create a bar chart to show the highest-paying job titles and their distribution
plt.figure(figsize=(16, 8))
sns.barplot(x='salary_in_usd', y='job_title', data=df_top_jobs, order=top_job_titles, palette=palette)
plt.title('Top 10 Job Titles with Highest Median Salaries')
plt.xlabel('Median Salary (USD)')
plt.ylabel('Job Title')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19884\1644088126.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='salary_in_usd', y='job_title', data=df_top_jobs, order=top_job_titles, palette=palette)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19884\1644088126.py:12: UserWarning:
# The palette list has fewer values (8) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='salary_in_usd', y='job_title', data=df_top_jobs, order=top_job_titles, palette=palette)

# %% [markdown]
# #### This code identifies the top 20 job titles with the highest median salary and creates a horizontal bar chart to visualize their salary distributions. The y-axis represents job titles, and the x-axis shows the salary in USD.

# %% [markdown]
# ## Explore the impact of remote work on salaries

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='remote_ratio', y='salary_in_usd', data=df)
plt.title('Impact of Remote Work on Salaries')
plt.xlabel('Remote Ratio')
plt.ylabel('Salary (USD)')
plt.show()

# Calculate the correlation between remote work ratio and salary
correlation = df['remote_ratio'].corr(df['salary_in_usd'])
print(f"Correlation between Remote Work Ratio and Salary: {correlation:.2f}")
# Out:
# Correlation between Remote Work Ratio and Salary: -0.06

# %% [markdown]
# #### The scatter plot will visualize the relationship between the remote work ratio and salaries, helping us identify any potential patterns. Additionally, the correlation coefficient will provide a quantitative measure of the strength and direction of the linear relationship between these two variables.

# %% [markdown]
# ### Explore the impact of company size

# %%
# Define a color palette for the company sizes
palette = sns.color_palette("Paired")

plt.figure(figsize=(16, 8))
sns.violinplot(x='company_size', y='salary_in_usd', data=df, order=['S', 'M', 'L', 'XL', 'XXL'], inner='quartile', palette=palette)
plt.title('Impact of Company Size on Salaries')
plt.xlabel('Company Size')
plt.ylabel('Salary (USD)')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19884\2044182344.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='company_size', y='salary_in_usd', data=df, order=['S', 'M', 'L', 'XL', 'XXL'], inner='quartile', palette=palette)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19884\2044182344.py:5: UserWarning: The palette list has more values (12) than needed (5), which may not be intended.
#   sns.violinplot(x='company_size', y='salary_in_usd', data=df, order=['S', 'M', 'L', 'XL', 'XXL'], inner='quartile', palette=palette)

# %% [markdown]
# ### Explore yearly trends in salaries

# %%
# Explore yearly trends in salaries
plt.figure(figsize=(14, 8))
sns.lineplot(x='work_year', y='salary_in_usd', data=df, errorbar=None)
plt.title('Yearly Trends in Salaries')
plt.xlabel('Year')
plt.ylabel('Average Salary (USD)')
plt.show()

# %% [markdown]
# ### Count Plot for Experience Levels

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='experience_level', data=df, palette='viridis')
plt.title('Distribution of Experience Levels')
plt.xlabel('Experience Level')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19884\3654143560.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='experience_level', data=df, palette='viridis')

# %% [markdown]
# ### Bar Chart for Employment Types

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='employment_type', data=df, palette='viridis')
plt.title('Distribution of Employment Types')
plt.xlabel('Employment Type')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19884\3885344548.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='employment_type', data=df, palette='viridis')
